# %%
import heapq
import networkx as nx
import matplotlib.pyplot as plt

# --- Union-Find for Kruskal ---
class UnionFind:
    def __init__(self, n):
        self.parent = list(range(n))
        self.rank = [0] * n

    def find(self, x):
        if self.parent[x] != x:
            self.parent[x] = self.find(self.parent[x])  # Path compression
        return self.parent[x]

    def union(self, x, y):
        rx, ry = self.find(x), self.find(y)
        if rx == ry:
            return False
        if self.rank[rx] < self.rank[ry]:
            rx, ry = ry, rx
        self.parent[ry] = rx
        if self.rank[rx] == self.rank[ry]:
            self.rank[rx] += 1
        return True


def kruskal(n, edges):
    edges.sort()
    uf = UnionFind(n)
    mst = []
    cost = 0

    for w, u, v in edges:
        if uf.union(u, v):
            mst.append((u, v, w))
            cost += w
            if len(mst) == n - 1:
                break

    return mst, cost


def prim(n, adj, start=0):
    INF = float('inf')
    key = [INF] * n
    parent = [-1] * n
    inMST = [False] * n

    key[start] = 0
    pq = [(0, start)]
    mst = []
    cost = 0

    while pq:
        w, u = heapq.heappop(pq)

        if inMST[u]:
            continue

        inMST[u] = True

        if parent[u] != -1:
            mst.append((parent[u], u, w))
            cost += w

        for v, wt in adj.get(u, []):
            if not inMST[v] and wt < key[v]:
                key[v] = wt
                parent[v] = u
                heapq.heappush(pq, (wt, v))

    return mst, cost


# ---------- Graph Visualization ----------
def draw_graph(edges, mst_edges, title):
    G = nx.Graph()

    # Add all edges
    for w, u, v in edges:
        G.add_edge(u, v, weight=w)

    # Fixed layout for consistent visualization
    pos = nx.spring_layout(G, seed=42)

    plt.figure(figsize=(8, 6))
    plt.title(title, fontsize=14)

    # Draw all nodes
    nx.draw_networkx_nodes(
        G, pos,
        node_color="lightblue",
        node_size=700
    )

    # Draw all edges
    nx.draw_networkx_edges(
        G, pos,
        edge_color="gray",
        width=2
    )

    # Highlight MST edges
    mst = [(u, v) for u, v, w in mst_edges]
    nx.draw_networkx_edges(
        G, pos,
        edgelist=mst,
        edge_color="red",
        width=4
    )

    # Draw labels
    nx.draw_networkx_labels(
        G, pos,
        font_size=12,
        font_weight="bold"
    )

    # Edge weight labels
    edge_labels = {(u, v): w for w, u, v in edges}
    nx.draw_networkx_edge_labels(
        G,
        pos,
        edge_labels=edge_labels,
        font_color="blue"
    )

    plt.axis("off")
    plt.show()


# ---------- Graph Definition ----------
n = 7
edges = [
    (7, 0, 1),
    (5, 0, 3),
    (8, 1, 2),
    (9, 1, 3),
    (7, 1, 4),
    (5, 2, 4),
    (15, 3, 4),
    (6, 3, 5),
    (8, 4, 5),
    (9, 4, 6),
    (11, 5, 6)
]

adj = {}

for w, u, v in edges:
    adj.setdefault(u, []).append((v, w))
    adj.setdefault(v, []).append((u, w))

# Run algorithms
k_mst, k_cost = kruskal(n, edges[:])
p_mst, p_cost = prim(n, adj)

# Print Results
print("=== Kruskal's MST ===")
for u, v, w in k_mst:
    print(f"Edge ({u} - {v})  Weight: {w}")
print("Total MST Cost:", k_cost)

print("\n=== Prim's MST ===")
for u, v, w in p_mst:
    print(f"Edge ({u} - {v})  Weight: {w}")
print("Total MST Cost:", p_cost)

# Draw Graphs
draw_graph(edges, k_mst, "Kruskal's Minimum Spanning Tree")
draw_graph(edges, p_mst, "Prim's Minimum Spanning Tree")
# Out:
# === Kruskal's MST ===
# Edge (0 - 3)  Weight: 5
# Edge (2 - 4)  Weight: 5
# Edge (3 - 5)  Weight: 6
# Edge (0 - 1)  Weight: 7
# Edge (1 - 4)  Weight: 7
# Edge (4 - 6)  Weight: 9
# Total MST Cost: 39
#
# === Prim's MST ===
# Edge (0 - 3)  Weight: 5
# Edge (3 - 5)  Weight: 6
# Edge (0 - 1)  Weight: 7
# Edge (1 - 4)  Weight: 7
# Edge (4 - 2)  Weight: 5
# Edge (4 - 6)  Weight: 9
# Total MST Cost: 39
